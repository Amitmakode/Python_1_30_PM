# %%
import pymongo
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\amitm\\Desktop\\Financial_dataset.csv")

# %%
df.head()
# Out:
#     Age  Annual_Income  Monthly_Expenses  Savings_Rate  Debt_to_Income_Ratio  \
# 0  45.0      686081.81          17942.27          0.29                  0.25
# 1   NaN      796474.39          55385.20          0.12                  0.55
# 2  46.0      708707.11               NaN          0.29                  0.38
# 3  55.0      940641.40          55378.16          0.11                  0.18
# 4  38.0     1452826.39          74823.60          0.29                  0.75
#
#    Current_Investments_Value  Total_Loan_Amount  Avg_Credit_Score  \
# 0                 1807462.47          556913.97             651.0
# 1                 2935502.53          563982.05             728.0
# 2                 1569022.45          479932.78             748.0
# 3                 3154348.23          484769.37             686.0
# 4                 4180505.40          839038.16             593.0
#
#    Inflation_Rate  Interest_Rate  Years_of_Employment  Job_Stability_Score  \
# ...

# %%
data  = df.to_dict("records")

# %%
url  = "mongodb+srv://amitkm644:<passwaord>@cluster0.dlsd0u0.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
url
# Out:
# 'mongodb+srv://amitkm644:12345@cluster0.dlsd0u0.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
# Create a MongoClient instance using the URI
client = pymongo.MongoClient(url)

# %%
#we are creating database as a client
database = client["AIML"]

# %%
# creating collection as a table in sql
collection = database["Financials"]

# %%
# Insert into MongoDB
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('688b1601e4f1371b20ba536f'), ObjectId('688b1601e4f1371b20ba5370'), ObjectId('688b1601e4f1371b20ba5371'), ObjectId('688b1601e4f1371b20ba5372'), ObjectId('688b1601e4f1371b20ba5373'), ObjectId('688b1601e4f1371b20ba5374'), ObjectId('688b1601e4f1371b20ba5375'), ObjectId('688b1601e4f1371b20ba5376'), ObjectId('688b1601e4f1371b20ba5377'), ObjectId('688b1601e4f1371b20ba5378'), ObjectId('688b1601e4f1371b20ba5379'), ObjectId('688b1601e4f1371b20ba537a'), ObjectId('688b1601e4f1371b20ba537b'), ObjectId('688b1601e4f1371b20ba537c'), ObjectId('688b1601e4f1371b20ba537d'), ObjectId('688b1601e4f1371b20ba537e'), ObjectId('688b1601e4f1371b20ba537f'), ObjectId('688b1601e4f1371b20ba5380'), ObjectId('688b1601e4f1371b20ba5381'), ObjectId('688b1601e4f1371b20ba5382'), ObjectId('688b1601e4f1371b20ba5383'), ObjectId('688b1601e4f1371b20ba5384'), ObjectId('688b1601e4f1371b20ba5385'), ObjectId('688b1601e4f1371b20ba5386'), ObjectId('688b1601e4f1371b20ba5387'), ObjectId('688b1601e4f1371b20ba
# ...
